# %% [markdown]
# ## 파이토치 시작
#
# ### 파이토치
# - https://pytorch.org
# - https://www.ultralytics.com/ko 와 손을 잡고 YOLO 개발
#     - 물체인식, 영상인식 분야에 트렌드
#
# <img src='../image/ml0016.png' width='600'>

# %% [markdown]
# #### 파이토치 GPU와 같이 사용하려면
# - NVIDIA CUDA 설치, 확인
# - cuDNN(CUDA 상에서 사용하는 여러 패키지) 설치
# - CUDA 버전에 맞는 PyTorch를 설치
#
# #### Tensorflow GPU
# - NVIDIA CUDA 상에서 동작
# - 윈도우에서는 설치가 무지 어렵다

# %% [markdown]
# #### NVIDIA 설정
# ```shell
# >  nvidia-smi
# - 그래픽카드 설명 표시
# ```
# - NVIDIA GeForce RTX...표시가되면 사용가능

# %% [markdown]
# ###### CUDA설치
# - https://developer.nvidia.com/cuda-11-8-0-download-archive
#
#     - Operating System : windows
#     - Architecture : x86_64
#     - Installer Type : exe(local)
#     - Base Installer : Download(3.0GB) 클릭

# %% [markdown]
# ###### cuDNN 11.8
# - https://developer.nvidia.com/rdp/cudnn-archive
#     - Download cuDNN v8.7.0(November 28th, 2022), for CUDA 11.x
#
# -  압축해제 후 CUDA 위치에 붙여넣기하면 끝
#
# - 터미널 또는 파워쉘에서
#
# ```shell
# nvcc --version
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:41:10_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0
# ```

# %% [markdown]
# #### PyTorch 설치
# <img src='../image/ml0017.png' width='700'>
#
#
# - 새터미널 실행후
# - mlvenv\Scripts\activate 입력후
# - 콘솔에서 아래 명령어를 실행
#
#
# ```shell
# > pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# ```
#
# ### 파이토치 확인

# %%
# 파이토치 모듈 사용
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda')
